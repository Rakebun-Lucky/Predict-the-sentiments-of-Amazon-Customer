# %%
import pandas as pd
import numpy as np

df = pd.read_csv('E:\Projects\Amazon use-case\Reviews.csv')

# %%
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
df.columns
# Out:
# Index(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')

# %%
df['Helpful%'] = np.where(df['HelpfulnessDenominator']>0,df['HelpfulnessNumerator']/df['HelpfulnessDenominator'],-1)

# %%
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text  \
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
df['Helpful%'].unique()
# Out:
# array([ 1.        , -1.        ,  0.8       ,  0.        ,  0.5       ,
#         0.66666667,  0.25      ,  0.89473684,  0.83333333,  0.75      ,
#         0.33333333,  0.3       ,  0.11111111,  0.42857143,  0.875     ,
#         0.85714286,  0.2       ,  0.26315789,  0.6       ,  0.71428571,
#         0.53846154,  0.57142857,  0.91489362,  0.86666667,  0.82352941,
#         0.78571429,  0.74074074,  0.4       ,  0.375     ,  0.28571429,
#         0.14285714,  0.77777778,  0.125     ,  0.9       ,  0.94117647,
#         0.92307692,  0.7       ,  0.45454545,  0.88888889,  0.83870968,
#         0.9047619 ,  0.92857143,  0.90909091,  0.91666667,  0.84615385,
#         0.10526316,  0.98214286,  0.97826087,  0.7518797 ,  0.3125    ,
#         0.1       ,  0.18518519,  0.88      ,  0.69230769,  0.625     ,
#         0.54545455,  0.41666667,  0.45833333,  0.22222222,  0.81818182,
#         0.8125    ,  0.16666667,  0.93103448,  0.88235294,  0.23529412,
# ...

# %%
df['%upvote'] = pd.cut(df['Helpful%'],bins=[-1,0,0.2,0.4,0.6,0.8,1],labels=['Empty','0-20%','20-40%','40-60%','60-80%','80-100%'])

# %%
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text  \
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
df.groupby(['Score','%upvote']).agg('count')
# Out:
#                    Id  ProductId  UserId  ProfileName  HelpfulnessNumerator  \
# Score %upvote
# 1     Empty      8060       8060    8060         8060                  8060
#       0-20%      2338       2338    2338         2338                  2338
#       20-40%     4649       4649    4649         4649                  4649
#       40-60%     6586       6586    6586         6586                  6586
#       60-80%     5838       5838    5838         5836                  5838
#       80-100%   12531      12531   12531        12531                 12531
# 2     Empty      4234       4234    4234         4234                  4234
#       0-20%       762        762     762          762                   762
#       20-40%     1618       1618    1618         1618                  1618
#       40-60%     3051       3051    3051         3051                  3051
#       60-80%     2486       2486    2486         2486                  2486
# ...

# %%
df_s = df.groupby(['Score','%upvote']).agg({'Id':'count'}).reset_index()

# %%
df_s
# Out:
#     Score  %upvote      Id
# 0       1    Empty    8060
# 1       1    0-20%    2338
# 2       1   20-40%    4649
# 3       1   40-60%    6586
# 4       1   60-80%    5838
# 5       1  80-100%   12531
# 6       2    Empty    4234
# 7       2    0-20%     762
# 8       2   20-40%    1618
# 9       2   40-60%    3051
# 10      2   60-80%    2486
# 11      2  80-100%    7014
# 12      3    Empty    5062
# 13      3    0-20%     474
# 14      3   20-40%    1506
# 15      3   40-60%    3384
# 16      3   60-80%    2754
# 17      3  80-100%   11037
# 18      4    Empty    4780
# 19      4    0-20%     116
# 20      4   20-40%     909
# 21      4   40-60%    3185
# 22      4   60-80%    2941
# 23      4  80-100%   26707
# 24      5    Empty   11638
# 25      5    0-20%     432
# 26      5   20-40%    2275
# 27      5   40-60%   10312
# 28      5   60-80%   11060
# 29      5  80-100%  140661

# %%
pivot = df_s.pivot(index='%upvote',columns='Score')

# %%
pivot
# Out:
#             Id
# Score        1     2      3      4       5
# %upvote
# Empty     8060  4234   5062   4780   11638
# 0-20%     2338   762    474    116     432
# 20-40%    4649  1618   1506    909    2275
# 40-60%    6586  3051   3384   3185   10312
# 60-80%    5838  2486   2754   2941   11060
# 80-100%  12531  7014  11037  26707  140661

# %%
import seaborn as sns

sns.heatmap(pivot,annot=True,cmap='YlGnBu')
# Out:
# <AxesSubplot:xlabel='None-Score', ylabel='%upvote'>

# %%
df['Score'].unique()
# Out:
# array([5, 1, 4, 2, 3], dtype=int64)

# %%
df2 = df[df['Score']!=3]

# %%
X = df2['Text']

# %%
df2['Score'].unique()
# Out:
# array([5, 1, 4, 2], dtype=int64)

# %%
y_dict = {1:0,2:0,4:1,5:1}
y = df2['Score'].map(y_dict)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
c = CountVectorizer(stop_words='english')

# %%
X_c = c.fit_transform(X)

# %%
X_c.shape
# Out:
# (525814, 114969)

# %%
import sklearn
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(X_c, y, test_size=0.3)

# %%
x_train.shape
# Out:
# (368069, 114969)

# %%
from sklearn.linear_model import LogisticRegression

# %%
log = LogisticRegression()

# %%
ml = log.fit(x_train,y_train)
# Out:
# C:\Users\Acer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
ml.score(x_test,y_test)
# Out:
# 0.935719040223145

# %%
w = c.get_feature_names()
w
# Out:
# ['00',
#  '000',
#  '0000',
#  '000001',
#  '00001',
#  '000013',
#  '0000soo',
#  '0001',
#  '000111052',
#  '0002251337',
#  '0003',
#  '0004',
#  '000iu',
#  '000kwh',
#  '000mg',
#  '000mi',
#  '000s',
#  '000su',
#  '000usd',
#  '000v',
#  '001',
#  '00100',
#  '00127',
#  '00128',
#  '00129',
#  '00130',
#  '00131',
#  '00132',
#  '00134',
#  '00136',
#  '00139',
#  '001bru',
#  '002',
#  '0020100604',
#  '00202',
#  '00227',
#  '0023',
#  '003',
#  '004',
#  '00493',
#  '005',
#  '00533',
#  '0060187654',
#  '0060721855',
#  '0060928115',
#  '0060959584',
#  '0061658197',
#  '006176793x',
#  '0067575986',
#  '0069615',
#  '007',
#  '00703',
#  '00704',
#  '0071468633',
#  '0071477845',
#  '0071486011',
#  '0071499849',
#  '008',
#  '0099',
#  '00a',
#  '00am',
#  '00b',
#  '00gr',
#  '00lb',
#  '00m',
#  '00pm',
#  '00s',
#  '00something',
#  '00z',
#  '01',
#  '010',
#  '0100',
#  '01014',
#  '01069',
#  '011',
#  '012',
#  '013',
#  '01317',
#  '01318',
#  '014',
# ...

# %%
coef = ml.coef_.tolist()[0]
coef
# Out:
# [-0.3605496234427782,
#  0.12570251131854,
#  0.4256127418579166,
#  -0.0016003404063465439,
#  -0.011388760522450712,
#  0.0,
#  0.0004662670038826887,
#  -0.010064701892132124,
#  0.0007329148402268557,
#  0.0,
#  0.001276173932392355,
#  -0.01297375372782985,
#  0.0010481119394153055,
#  0.013016521199740746,
#  -0.5329126789878436,
#  0.002185817679861505,
#  0.0017316785233149768,
#  0.00466121938003674,
#  0.0005906016235926645,
#  6.164657006768095e-05,
#  0.1287552425633559,
#  0.02017641672691025,
#  0.04389325294045947,
#  0.04389325294045947,
#  0.04389325294045947,
#  0.04389325294045947,
#  0.04389325294045947,
#  0.04389325294045947,
#  0.04389325294045947,
#  0.04389325294045947,
#  0.04389325294045947,
#  0.0,
#  0.0910390540858684,
#  0.0,
#  0.0,
#  -0.0005545749121386796,
#  0.0,
#  0.004131928184383963,
#  0.052809073816432205,
#  0.0,
#  0.0,
#  0.012541573609856867,
#  7.655010792582787e-05,
#  0.004240562068424088,
#  -0.10037265161101457,
# ...

# %%
coef_df = pd.DataFrame({'Word':w,'Coefficient':coef})
coef_df
# Out:
#           Word  Coefficient
# 0           00    -0.360550
# 1          000     0.125703
# 2         0000     0.425613
# 3       000001    -0.001600
# 4        00001    -0.011389
# ...        ...          ...
# 114964  çaykur     0.001155
# 114965   çelem    -0.128118
# 114966    être     0.000000
# 114967     île     0.013532
# 114968      ît     0.000401
#
# [114969 rows x 2 columns]

# %%
coef_df=coef_df.sort_values(['Coefficient','Word'],ascending=False)

# %%
coef_df.head(20) #top 20 positive words based on coefficients
# Out:
#               Word  Coefficient
# 80600   pleasantly     4.478593
# 39072     downside     3.432087
# 5865     addicting     3.042813
# 94667    skeptical     3.041257
# 87967       resist     2.822296
# 39214     drawback     2.724545
# 35726       delish     2.676982
# 105162     trainer     2.602275
# 111911        whim     2.506655
# 55029       hooked     2.447809
# 113138     worries     2.415011
# 96140       solved     2.400182
# 24746         calm     2.400044
# 40342   economical     2.382604
# 58320       intend     2.369860
# 68460          met     2.329400
# 96353     soothing     2.321530
# 54130     hesitant     2.307458
# 102857    terrific     2.295113
# 91064        saves     2.243148

# %%
coef_df.tail(20) #top 20 negative words based on coefficients
# Out:
#                   Word  Coefficient
# 21288            blech    -2.625182
# 94747             skip    -2.632982
# 37563   disappointment    -2.676012
# 110404         vomited    -2.695480
# 38117    dissapointing    -2.736455
# 35220          defeats    -2.745183
# 67898         mediocre    -2.762625
# 106852    unacceptable    -2.789603
# 62401           lacked    -2.857231
# 37528      disapointed    -2.921706
# 41118      embarrassed    -2.943101
# 88351       returnable    -2.996548
# 106940      unbearable    -3.010972
# 65064            lousy    -3.125594
# 37560    disappointing    -3.305732
# 24949        cancelled    -3.317543
# 113164           worst    -3.333682
# 88945           ripoff    -3.690082
# 107383     undrinkable    -4.225878
# 34989        deceptive    -4.534514

# %%
def text_fit(x,y,nlp_model,ml_model,coef_show):
    X_c=nlp_model.fit_transform(x)
    print('feature:{}'.format(X_c.shape[1]))
    x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(X_c, y, test_size=0.3)
    ml = ml_model.fit(x_train,y_train)
    acc = ml.score(x_test,y_test)
    print(acc)
    
    if coef_show==1:
        w = c.get_feature_names()
        coef = ml.coef_.tolist()[0]
        coef_df = pd.DataFrame({'Word':w,'Coefficient':coef})
        coef_df=coef_df.sort_values(['Coefficient','Word'],ascending=False)
        print('\n')
        print('-Top 20 Positive words')
        print(coef_df.head(20))
        print('-Top 20 Negative words')
        print(coef_df.tail(20))

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
c = CountVectorizer(stop_words='english')

# %%
from sklearn.linear_model import LogisticRegression

# %%
text_fit(X,y,c,LogisticRegression(),1)
# Out:
# feature:114969
# C:\Users\Acer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.9353006434435323
#
#
# -Top 20 Positive words
#               Word  Coefficient
# 80600   pleasantly     3.960352
# 39072     downside     3.475991
# 5865     addicting     2.970252
# 94667    skeptical     2.910109
# 87967       resist     2.425091
# 55029       hooked     2.360190
# 35726       delish     2.317406
# 39214     drawback     2.218915
# 96140       solved     2.124211
# 54137   hesitation     2.052505
# ...

# %%
from sklearn.metrics import confusion_matrix,accuracy_score

def predict(x,y,nlp_model,ml_model):
    X_c=nlp_model.fit_transform(x)
    x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(X_c, y, test_size=0.3)
    ml = ml_model.fit(x_train,y_train)
    predictions = ml.predict(x_test)
    cm = confusion_matrix(predictions,y_test)
    print(cm)
    acc = accuracy_score(predictions,y_test)
    print(acc)

# %%
c = CountVectorizer()
lr = LogisticRegression()

predict(X,y,c,lr)
# Out:
# C:\Users\Acer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [[ 17943   3334]
#  [  6637 129831]]
# 0.9367903895527592

# %%
from sklearn.dummy import DummyClassifier

# %%
c = CountVectorizer()

# %%
text_fit(X,y,c,DummyClassifier(),0)
# Out:
# feature:115282
# C:\Users\Acer\anaconda3\lib\site-packages\sklearn\dummy.py:131: FutureWarning: The default value of strategy will change from stratified to prior in 0.24.
#   warnings.warn("The default value of strategy will change from "
# 0.7371580715712067

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(stop_words='english')
lr = LogisticRegression()

# %%
text_fit(X,y,tfidf,lr,0)
# Out:
# feature:114969
# 0.9343307236362484
# C:\Users\Acer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text  \
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
data = df[df['Score']==5]
data.head()
# Out:
#    Id   ProductId          UserId                    ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                     delmartian
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T  Michael D. Bigham "M. Wassir"
# 6   7  B006K2ZZ7K  A1SP2KVKFXXRU1              David C. Sullivan
# 7   8  B006K2ZZ7K  A3JRGQVEQN31IQ             Pamela G. Williams
# 8   9  B000E7L2R4  A1MZYO9TZK0BBI                       R. James
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 4                     0                       0      5  1350777600
# 6                     0                       0      5  1340150400
# 7                     0                       0      5  1336003200
# 8                     1                       1      5  1322006400
#
#                                          Summary  \
# 0                          Good Quality Dog Food
# 4                                    Great taffy
# ...

# %%
data['%upvote'].unique()
# Out:
# ['80-100%', NaN, '60-80%', 'Empty', '40-60%', '20-40%', '0-20%']
# Categories (6, object): ['Empty' < '0-20%' < '20-40%' < '40-60%' < '60-80%' < '80-100%']

# %%
data2 = data[data['%upvote'].isin(['80-100%', '60-80%', '20-40%', '0-20%'])]
data2.head()
# Out:
#     Id   ProductId          UserId             ProfileName  \
# 0    1  B001E4KFG0  A3SGXH7AUHU8GW              delmartian
# 8    9  B000E7L2R4  A1MZYO9TZK0BBI                R. James
# 10  11  B0001PB9FE  A3HDKO7OW0QNK4            Canadian Fan
# 11  12  B0009XLVG0  A2725IB4YY9JEB  A Poeng "SparkyGoHome"
# 14  15  B001GVISJM  A2MUGFV2TDQ47K     Lynrie "Oh HELL no"
#
#     HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                      1                       1      5  1303862400
# 8                      1                       1      5  1322006400
# 10                     1                       1      5  1107820800
# 11                     4                       4      5  1282867200
# 14                     4                       5      5  1268352000
#
#                                               Summary  \
# 0                               Good Quality Dog Food
# 8                                          Yay Barley
# ...

# %%
X = data2['Text']
data2['%upvote'].unique()
# Out:
# ['80-100%', '60-80%', '20-40%', '0-20%']
# Categories (4, object): ['0-20%' < '20-40%' < '60-80%' < '80-100%']

# %%
y_dict = {'80-100%':1, '60-80%':1, '20-40%':0, '0-20%':0}
y = data2['%upvote'].map(y_dict)

# %%
y.value_counts()
# Out:
# 1.0    151721
# 0.0      2707
# Name: %upvote, dtype: int64

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tf = TfidfVectorizer()

# %%
X_c = tf.fit_transform(X)

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
os = RandomOverSampler()

# %%
X_train_ros, y_train_ros = os.fit_sample(X_c,y)

# %%
X_train_ros.shape
# Out:
# (303442, 67507)

# %%
y_train_ros.shape
# Out:
# (303442,)

# %%
from collections import Counter

# %%
print('Original Dataset Shape {}'.format(Counter(y)))
print('Resampled Dataset Shape {}'.format(Counter(y_train_ros)))
# Out:
# Original Dataset Shape Counter({1.0: 151721, 0.0: 2707})
# Resampled Dataset Shape Counter({1.0: 151721, 0.0: 151721})

# %%
from sklearn.linear_model import LogisticRegression
log_class = LogisticRegression()

# %%
np.arange(-2,3)
# Out:
# array([-2, -1,  0,  1,  2])

# %%
grid={'C':10.0 **np.arange(-2,3),'penalty':['l1','l2']}

# %%
from sklearn.model_selection import GridSearchCV

# %%
clf = GridSearchCV(estimator=log_class,param_grid=grid,cv=5,n_jobs=-1,scoring='f1_macro')

# %%
clf.fit(X_train_ros,y_train_ros)
# Out:
# C:\Users\Acer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# GridSearchCV(cv=5, estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'C': array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02]),
#                          'penalty': ['l1', 'l2']},
#              scoring='f1_macro')

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(X_c,y)

# %%
pred = clf.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[  681,     0],
#        [  648, 37278]], dtype=int64)

# %%
accuracy_score(y_test,pred)
# Out:
# 0.9832154790582018
